# %% [markdown]
# <a href="https://colab.research.google.com/github/urfa10/MSIB_Dasar-Python/blob/main/session_7_BasicViz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Simple Visualization using Pandas, Matplotlib, Seaborn

# %%
# google drive connection
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = '/content/drive/MyDrive/PDA_DataSource/Data Visualization/telco_customer.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Scatter plot: Tenure dan Monthly Charges
# ### Plot Pandas

# %%
df.plot(x='tenure', y='MonthlyCharges', kind='scatter');

# %% [markdown]
# ### Plot Matplotlib

# %%
plt.scatter(x='tenure', y='MonthlyCharges', data=df);

# %% [markdown]
# ### Plot Seaborn

# %%
sns.scatterplot(x='tenure', y='MonthlyCharges', data=df);

# %%
# Menggunakan sampling untuk mengatasi overlapping plot
df.shape
# Out:
# (7043, 21)

# %%
df_sample = df.sample(700, random_state=14)

# %%
sns.scatterplot(x='tenure', y='MonthlyCharges', data=df_sample);

# %% [markdown]
# ## Histogram: Find Distribution of MonthlyCharges

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# Challenge
# Buatkan visualisaasi distribusi dari MonthlyCharges menggunakan pandas, matplotlib, seaborn

# %% [markdown]
# ### Plot Pandas

# %%
df.plot(x='MonthlyCharges', kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['MonthlyCharges'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'SeniorCitizen'}>,
#         <Axes: title={'center': 'tenure'}>],
#        [<Axes: title={'center': 'MonthlyCharges'}>, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Matplotlib

# %%
plt.hist(x='MonthlyCharges', data=df);

# %% [markdown]
# ### seaborn

# %%
sns.histplot(x='MonthlyCharges', data=df)
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='Count'>

# %%
sns.displot(x='MonthlyCharges', data=df, kde=True)

# %% [markdown]
# ## Boxplot: Tenure
# ### Pandas

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df['tenure'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.boxplot(column='tenure', by='Churn', grid=False)
# Out:
# <Axes: title={'center': 'tenure'}, xlabel='Churn'>

# %% [markdown]
# ### Matplotlib

# %%
plt.boxplot(x='tenure', data=df, vert=False);

# %% [markdown]
# ### seaborn

# %%
sns.boxplot(x='tenure', data=df)
# Out:
# <Axes: xlabel='tenure'>

# %%
sns.boxplot(x='tenure', y='PaymentMethod', data=df)
# Out:
# <Axes: xlabel='tenure', ylabel='PaymentMethod'>

# %%
sns.displot(x='tenure', hue='PaymentMethod', data=df, kind='kde');

# %% [markdown]
# ## Barplot: Compare Average MonthlyCharges by PaymentMethod

# %%
dfg = df.groupby('PaymentMethod')['MonthlyCharges'].mean().reset_index()
dfg
# Out:
#                PaymentMethod  MonthlyCharges
# 0  Bank transfer (automatic)       67.192649
# 1    Credit card (automatic)       66.512385
# 2           Electronic check       76.255814
# 3               Mailed check       43.917060

# %% [markdown]
# ### Pandas

# %%
dfg.plot(x='PaymentMethod', y='MonthlyCharges', kind='bar')
# Out:
# <Axes: xlabel='PaymentMethod'>

# %%
dfg.plot(x='PaymentMethod', y='MonthlyCharges', kind='barh')
# Out:
# <Axes: ylabel='PaymentMethod'>

# %% [markdown]
# # Break Until 10.20

# %%
dfg.plot(x='PaymentMethod', y='MonthlyCharges', kind='bar',
         color='red',
         legend=False,
         rot=0,
         figsize=(10,6));

# %% [markdown]
# ### matplotlib

# %%
plt.bar(x='PaymentMethod', height='MonthlyCharges', data=dfg)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(10, 6))
plt.bar(x='PaymentMethod', height='MonthlyCharges', data=dfg)
plt.title('Bar Chart monthly charge by payment method')
plt.show()

# %% [markdown]
# ### Seaborn

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='PaymentMethod', y='MonthlyCharges', data=dfg)
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='MonthlyCharges'>

# %%
# Agregasi langsung di dalam plot menggunakan seaborn
plt.figure(figsize=(10,6))
sns.barplot(x='PaymentMethod', y='MonthlyCharges', estimator='mean', data=df);

# %%
# Countplot in saeaborn
plt.figure(figsize=(10,6))
sns.countplot(x='PaymentMethod', data=df, hue='Churn')
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
url_degree = '/content/drive/MyDrive/PDA_DataSource/Data Visualization/percent-bachelors-degrees-women-usa.csv'
data = pd.read_csv(url_degree)
data.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
# 1  64.556485               73.9                75.5                 39.0
# 2  63.664263               74.6                76.9                 40.2
# 3  62.941502               74.9                77.4                 40.9
# 4  62.413412               75.3                77.9                 41.8
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
# 1               14.9        46.2                   65.5
# 2               14.8        47.6                   62.6
# 3               16.5        50.4                   64.3
# 4               18.2        52.6                   66.1
#
#    Social Sciences and History
# 0                         36.8
# 1                         36.2
# 2                         36.1
# 3                         36.4
# 4                         37.3

# %% [markdown]
# Challenge:
# - Buatkan boxplot untuk categori Engineering, Computer Science, Architecture
# - Untuk kategori tadi, buat bar plot pada data tahun 1970

# %%
# hint: lakukan filter terlebih dahulu
selected = ['Engineering', 'Computer Science', 'Architecture']
data[selected].plot(kind='box')
# Out:
# <Axes: >

# %%
sns.boxplot(data[selected])
# Out:
# <Axes: >

# %%
data_1970 = data[data['Year'] == 1970][selected]

# %%
data_1970
# Out:
#    Engineering  Computer Science  Architecture
# 0          0.8              13.6     11.921005

# %%
data_1970.plot(kind='bar')
# Out:
# <Axes: >

# %%
# matplotlib boxplot

# %% [markdown]
# ## Multi-Bar: Average tenure by payment method and churn

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='tenure', y='PaymentMethod', hue='Churn', data=df)
# Out:
# <Axes: xlabel='tenure', ylabel='PaymentMethod'>

# %% [markdown]
# ## Save Plot

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='MonthlyCharges', y='PaymentMethod', data=df, estimator='sum')

# save plot
plt.savefig('firstplot.png')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='MonthlyCharges', y='PaymentMethod', data=df, estimator='sum')

# save plot
plt.tight_layout()
plt.savefig('firstplot.png', dpi=200)

# %% [markdown]
# ## Lineplot

# %%
plt.plot([1,2,3,4])

# %%
plt.plot('Year', 'Computer Science', data=data)
plt.plot('Year', 'Engineering', data=data)
plt.plot('Year', 'Architecture', data=data)
plt.legend(loc='lower center')
plt.title('Selected Field on Year')
plt.xlabel('Year')
plt.ylabel('Percentage Women')
plt.text(x=1990, y=15, s='Engineering', rotation=30, color='red')
plt.show()
